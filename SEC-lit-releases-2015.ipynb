# %%
import pandas as pd
import re
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('SEC_lit_releases_2015.csv')

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df.head()
# Out:
#   Release No.           Date  \
# 0  LR-23440    Dec. 28, 2015
# 1  LR-23439    Dec. 23, 2015
# 2  LR-23438    Dec. 23, 2015
# 3  LR-23437    Dec. 23, 2015
# 4  LR-23436    Dec. 22, 2015
#
#                                                                                             Action
# 0  New Stream Capital, LLC, et al. Other Release No.: AAER-3730
# 1  Michael J. Ling
# 2  Bonan Huang, et al.
# 3  In re Four Points Capital Partners LLC
# 4  Southern Cross Resources Group, Inc., et al. See also: SEC Complaint, Administrative Proceeding

# %%
# make a new column of lowercase release numbers to generate URL column
df['release_no'] = df['Release No.'].str.replace('-', '')
df['release_no'] = df['release_no'].str.lower()

# %%
# add the url column based on the url pattern
df['url'] = "https://www.sec.gov/litigation/litreleases/2015/" + df.release_no + ".htm"

# %%
# drop the release_no column
df = df.drop(['release_no'], axis=1)

# %%
df
# Out:
#     Release No.           Date  \
# 0    LR-23440    Dec. 28, 2015
# 1    LR-23439    Dec. 23, 2015
# 2    LR-23438    Dec. 23, 2015
# 3    LR-23437    Dec. 23, 2015
# 4    LR-23436    Dec. 22, 2015
# 5    LR-23435    Dec. 18, 2015
# 6    LR-23434    Dec. 18, 2015
# 7    LR-23433    Dec. 17, 2015
# 8    LR-23432    Dec. 17, 2015
# 9    LR-23431    Dec. 16, 2015
# 10   LR-23430    Dec. 16, 2015
# 11   LR-23429    Dec. 16, 2015
# 12   LR-23428    Dec. 15, 2015
# 13   LR-23427    Dec. 15, 2015
# 14   LR-23426    Dec. 14, 2015
# 15   LR-23425    Dec. 11, 2015
# 16   LR-23424    Dec. 11, 2015
# 17   LR-23423    Dec. 8, 2015
# 18   LR-23422    Dec. 8, 2015
# 19   LR-23421    Dec. 8, 2015
# 20   LR-23420    Dec. 7, 2015
# 21   LR-23419    Dec. 4, 2015
# 22   LR-23418    Dec. 3, 2015
# 23   LR-23417    Dec. 1, 2015
# 24   LR-23416    Dec. 1, 2015
# 25   LR-23415    Dec. 1, 2015
# 26   LR-23414    Nov. 27, 2015
# 27   LR-23413    Nov. 24, 2015
# 28   LR-23412    Nov. 23, 2015
# ...

# %%
# using BeautifulSoup to loop through each URL and pull all the text

def get_release_info(row):
    
    try:
        request = requests.get(row['url'])
        soup = BeautifulSoup(request.text, 'html.parser')
        
        full_text = soup.findAll(text=True)
        
    except:
        return pd.Series({})

    return pd.Series({
        'full_text': full_text,
    })

# %%
df_litreleases_2015 = df.apply(get_release_info, axis=1).join(df)

# %%
df_litreleases_2015.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df_litreleases_2015.dtypes
# Out:
# full_text      object
# Release No.    object
# Date           object
# Action         object
# url            object
# dtype: object

# %%
df_litreleases_2015['Respondents'] = df_litreleases_2015['Action']

# %%
# rearrange columns
df_litreleases_2015 = df_litreleases_2015[['Release No.','Respondents','Date','url', 'full_text']]
df_litreleases_2015.head()
# Out:
#   Release No.  \
# 0  LR-23440
# 1  LR-23439
# 2  LR-23438
# 3  LR-23437
# 4  LR-23436
#
#                                                                                        Respondents  \
# 0  New Stream Capital, LLC, et al. Other Release No.: AAER-3730
# 1  Michael J. Ling
# 2  Bonan Huang, et al.
# 3  In re Four Points Capital Partners LLC
# 4  Southern Cross Resources Group, Inc., et al. See also: SEC Complaint, Administrative Proceeding
#
#             Date                                                          url  \
# 0  Dec. 28, 2015  https://www.sec.gov/litigation/litreleases/2015/lr23440.htm
# 1  Dec. 23, 2015  https://www.sec.gov/litigation/litreleases/2015/lr23439.htm
# 2  Dec. 23, 2015  https://www.sec.gov/litigation/litreleases/2015/lr23438.htm
# 3  Dec. 23, 2015  https://www.sec.gov/litigation/litreleases/2015/lr23437.htm
# 4  Dec. 22, 2015  https://www.sec.gov/litigation/litreleases/2015/lr23436.htm
#
# ...

# %%
# Save to CSV
df_litreleases_2015.to_csv("litreleases_2015_scraped.csv", index=False)
