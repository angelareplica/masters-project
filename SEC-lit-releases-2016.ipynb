# %%
import pandas as pd
import re
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('SEC_lit_releases_2016.csv')

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df.head()
# Out:
#   Release No.           Date  \
# 0  LR-23714    Dec. 28, 2016
# 1  LR-23713    Dec. 28, 2016
# 2  LR-23712    Dec. 27, 2016
# 3  LR-23711    Dec. 27, 2016
# 4  LR-23710    Dec. 22, 2016
#
#                                            Respondents
# 0  AJN Investments, LLC et al. See also: SEC Complaint
# 1  Interinvest Corporation, Inc. et al.
# 2  Emilio Francisco, et al. See also: SEC Complaint
# 3  Iat Hong, et al. See also: SEC Complaint
# 4  Richard G. Cody, et al. See also: SEC Complaint

# %%
# make a new column of lowercase release numbers to generate URL column
df['release_no'] = df['Release No.'].str.replace('-', '')
df['release_no'] = df['release_no'].str.lower()

# %%
# add the url column based on the url pattern
df['url'] = "https://www.sec.gov/litigation/litreleases/2016/" + df.release_no + ".htm"

# %%
# drop the release_no column
df = df.drop(['release_no'], axis=1)

# %%
df
# Out:
#     Release No.           Date  \
# 0    LR-23714    Dec. 28, 2016
# 1    LR-23713    Dec. 28, 2016
# 2    LR-23712    Dec. 27, 2016
# 3    LR-23711    Dec. 27, 2016
# 4    LR-23710    Dec. 22, 2016
# 5    LR-23709    Dec. 22, 2016
# 6    LR-23708    Dec. 22, 2016
# 7    LR-23707    Dec. 21, 2016
# 8    LR-23706    Dec. 21, 2016
# 9    LR-23705    Dec. 21, 2016
# 10   LR-23704    Dec. 20, 2016
# 11   LR-23703    Dec. 20, 2016
# 12   LR-23702    Dec. 13, 2016
# 13   LR-23701    Dec. 8, 2016
# 14   LR-23700    Dec. 7, 2016
# 15   LR-23699    Dec. 5, 2016
# 16   LR-23698    Dec. 2, 2016
# 17   LR-23697    Dec. 1, 2016
# 18   LR-23696    Nov. 30, 2016
# 19   LR-23695    Nov. 30, 2016
# 20   LR-23694    Nov. 23, 2016
# 21   LR-23693    Nov. 23, 2016
# 22   LR-23692    Nov. 22, 2016
# 23   LR-23691    Nov. 22, 2016
# 24   LR-23690    Nov. 18, 2016
# 25   LR-23689    Nov. 16, 2016
# 26   LR-23688    Nov. 14, 2016
# 27   LR-23687    Nov. 9, 2016
# 28   LR-23686    Nov. 9, 2016
# ...

# %%
# using BeautifulSoup loop through each url and pull all the text behind it

def get_release_info(row):
    
    try:
        request = requests.get(row['url'])
        soup = BeautifulSoup(request.text, 'html.parser')
        
        full_text = soup.findAll(text=True)
        
    except:
        return pd.Series({})

    return pd.Series({
        'full_text': full_text,
    })

# %%
df_litreleases_16 = df.apply(get_release_info, axis=1).join(df)

# %%
df_litreleases_16.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df_litreleases_16.dtypes
# Out:
# full_text      object
# Release No.    object
# Date           object
# Respondents    object
# url            object
# dtype: object

# %%
df_litreleases_16 = df_litreleases_16[['Release No.','Respondents','Date','url', 'full_text']]
df_litreleases_16.head()
# Out:
#   Release No.                                          Respondents  \
# 0  LR-23714    AJN Investments, LLC et al. See also: SEC Complaint
# 1  LR-23713    Interinvest Corporation, Inc. et al.
# 2  LR-23712    Emilio Francisco, et al. See also: SEC Complaint
# 3  LR-23711    Iat Hong, et al. See also: SEC Complaint
# 4  LR-23710    Richard G. Cody, et al. See also: SEC Complaint
#
#             Date                                                          url  \
# 0  Dec. 28, 2016  https://www.sec.gov/litigation/litreleases/2016/lr23714.htm
# 1  Dec. 28, 2016  https://www.sec.gov/litigation/litreleases/2016/lr23713.htm
# 2  Dec. 27, 2016  https://www.sec.gov/litigation/litreleases/2016/lr23712.htm
# 3  Dec. 27, 2016  https://www.sec.gov/litigation/litreleases/2016/lr23711.htm
# 4  Dec. 22, 2016  https://www.sec.gov/litigation/litreleases/2016/lr23710.htm
#
# ...

# %%
# Save to CSV
df_litreleases_16.to_csv("litreleases_2016_scraped.csv", index=False)
