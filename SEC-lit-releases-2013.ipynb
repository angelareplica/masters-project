# %%
import pandas as pd
import re
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('SEC_lit_releases_2013.csv')

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df.head()
# Out:
#   Release No.           Date  \
# 0  LR-22900    Dec. 24, 2013
# 1  LR-22899    Dec. 23, 2013
# 2  LR-22898    Dec. 23, 2013
# 3  LR-22897    Dec. 23, 2013
# 4  LR-22896    Dec. 23, 2013
#
#                                                              Action
# 0  Archer-Daniels-Midland Company See also: SEC Complaint
# 1  David F. Marchand  See also: SEC Complaint
# 2  Dawn Wright-Olivares and Daniel Olivares See also: SEC Complaint
# 3  All Know Holdings Ltd., et al.
# 4  Mark A. Lefkowitz, et al.

# %%
# make a new column of lowercase release numbers to generate URL column
df['release_no'] = df['Release No.'].str.replace('-', '')
df['release_no'] = df['release_no'].str.lower()

# %%
# add the url column based on the url pattern
df['url'] = "https://www.sec.gov/litigation/litreleases/2013/" + df.release_no + ".htm"

# %%
# drop the release_no column
df = df.drop(['release_no'], axis=1)

# %%
df
# Out:
#     Release No.           Date  \
# 0    LR-22900    Dec. 24, 2013
# 1    LR-22899    Dec. 23, 2013
# 2    LR-22898    Dec. 23, 2013
# 3    LR-22897    Dec. 23, 2013
# 4    LR-22896    Dec. 23, 2013
# 5    LR-22895    Dec. 23, 2013
# 6    LR-22894    Dec. 20, 2013
# 7    LR-22893    Dec. 20, 2013
# 8    LR-22892    Dec. 18, 2013
# 9    LR-22891    Dec. 16, 2013
# 10   LR-22890    Dec. 16, 2013
# 11   LR-22889    Dec. 13, 2013
# 12   LR-22888    Dec. 13, 2013
# 13   LR-22887    Dec. 12, 2013
# 14   LR-22886    Dec. 6, 2013
# 15   LR-22885    Dec. 5, 2013
# 16   LR-22884    Dec. 4, 2013
# 17   LR-22883    Dec. 3, 2013
# 18   LR-22882    Dec. 3, 2013
# 19   LR-22881    Dec. 2, 2013
# 20   LR-22880    Nov. 26, 2013
# 21   LR-22879    Nov. 25, 2013
# 22   LR-22878    Nov. 25, 2013
# 23   LR-22877    Nov. 25, 2013
# 24   LR-22876    Nov. 21, 2013
# 25   LR-22875    Nov. 21, 2013
# 26   LR-22874    Nov. 21, 2013
# 27   LR-22873    Nov. 21, 2013
# 28   LR-22872    Nov. 21, 2013
# ...

# %%
# using BeautifulSoup to loop through each URL and pull all the text

def get_release_info(row):
    
    try:
        request = requests.get(row['url'])
        soup = BeautifulSoup(request.text, 'html.parser')
        
        full_text = soup.findAll(text=True)
        
    except:
        return pd.Series({})

    return pd.Series({
        'full_text': full_text,
    })

# %%
df_litreleases_2013 = df.apply(get_release_info, axis=1).join(df)

# %%
df_litreleases_2013.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df_litreleases_2013.dtypes
# Out:
# full_text      object
# Release No.    object
# Date           object
# Action         object
# url            object
# dtype: object

# %%
df_litreleases_2013['Respondents'] = df_litreleases_2013['Action']

# %%
# rearrange columns
df_litreleases_2013 = df_litreleases_2013[['Release No.','Respondents','Date','url', 'full_text']]
df_litreleases_2013.head()
# Out:
#   Release No.  \
# 0  LR-22900
# 1  LR-22899
# 2  LR-22898
# 3  LR-22897
# 4  LR-22896
#
#                                                         Respondents  \
# 0  Archer-Daniels-Midland Company See also: SEC Complaint
# 1  David F. Marchand  See also: SEC Complaint
# 2  Dawn Wright-Olivares and Daniel Olivares See also: SEC Complaint
# 3  All Know Holdings Ltd., et al.
# 4  Mark A. Lefkowitz, et al.
#
#             Date                                                          url  \
# 0  Dec. 24, 2013  https://www.sec.gov/litigation/litreleases/2013/lr22900.htm
# 1  Dec. 23, 2013  https://www.sec.gov/litigation/litreleases/2013/lr22899.htm
# 2  Dec. 23, 2013  https://www.sec.gov/litigation/litreleases/2013/lr22898.htm
# 3  Dec. 23, 2013  https://www.sec.gov/litigation/litreleases/2013/lr22897.htm
# 4  Dec. 23, 2013  https://www.sec.gov/litigation/litreleases/2013/lr22896.htm
#
# ...

# %%
# Save to CSV
df_litreleases_2013.to_csv("litreleases_2013_scraped.csv", index=False)
