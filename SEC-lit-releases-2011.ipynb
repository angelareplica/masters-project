# %%
import pandas as pd
import re
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('SEC_lit_releases_2011.csv')

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df.head()
# Out:
#   Release No.           Date  \
# 0  LR-22213    Dec. 29, 2011
# 1  LR-22212    Dec. 29, 2011
# 2  LR-22211    Dec. 28, 2011
# 3  LR-22210    Dec. 23, 2011
# 4  LR-22209    Dec. 22, 2011
#
#                                                                                                                                         Action
# 0  Magyar Telekom Plc. and Deutsche Telekom AG and Straub, et al. See also: SEC complaint v. the companies and SEC Complaint v. the executives
# 1  Shawn R. Merriman et al.
# 2  Evolution Capital Advisors, et al.
# 3  GE Funding Capital Market Services, Inc.
# 4  Alfred S. Teo, Sr., et al.

# %%
# make a new column of lowercase release numbers to generate URL column
df['release_no'] = df['Release No.'].str.replace('-', '')
df['release_no'] = df['release_no'].str.lower()

# %%
# add the url column based on the url pattern
df['url'] = "https://www.sec.gov/litigation/litreleases/2011/" + df.release_no + ".htm"

# %%
# drop the release_no column
df = df.drop(['release_no'], axis=1)

# %%
df
# Out:
#     Release No.           Date  \
# 0    LR-22213    Dec. 29, 2011
# 1    LR-22212    Dec. 29, 2011
# 2    LR-22211    Dec. 28, 2011
# 3    LR-22210    Dec. 23, 2011
# 4    LR-22209    Dec. 22, 2011
# 5    LR-22208    Dec. 22, 2011
# 6    LR-22207    Dec. 21, 2011
# 7    LR-22206    Dec. 21, 2011
# 8    LR-22205    Dec. 21, 2011
# 9    LR-22204    Dec. 20, 2011
# 10   LR-22203    Dec. 20, 2011
# 11   LR-22202    Dec. 20, 2011
# 12   LR-22201    Dec. 20, 2011
# 13   LR-22200    Dec. 16, 2011
# 14   LR-22199    Dec. 16, 2011
# 15   LR-22198    Dec. 16, 2011
# 16   LR-22197    Dec. 16, 2011
# 17   LR-22196    Dec. 16, 2011
# 18   LR-22195    Dec. 15, 2011
# 19   LR-22194    Dec. 15, 2011
# 20   LR-22193    Dec. 15, 2011
# 21   LR-22192    Dec. 13, 2011
# 22   LR-22191    Dec. 13, 2011
# 23   LR-22190    Dec. 13, 2011
# 24   LR-22189    Dec. 12, 2011
# 25   LR-22188    Dec. 12, 2011
# 26   LR-22187    Dec. 12, 2011
# 27   LR-22186    Dec. 9, 2011
# 28   LR-22185    Dec. 9, 2011
# ...

# %%
# using BeautifulSoup to loop through each URL and pull all the text

def get_release_info(row):
    
    try:
        request = requests.get(row['url'])
        soup = BeautifulSoup(request.text, 'html.parser')
        
        full_text = soup.findAll(text=True)
        
    except:
        return pd.Series({})

    return pd.Series({
        'full_text': full_text,
    })

# %%
df_litreleases_2011 = df.apply(get_release_info, axis=1).join(df)

# %%
df_litreleases_2011.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df_litreleases_2011.dtypes
# Out:
# full_text      object
# Release No.    object
# Date           object
# Action         object
# url            object
# dtype: object

# %%
df_litreleases_2011['Respondents'] = df_litreleases_2011['Action']

# %%
# rearrange columns
df_litreleases_2011 = df_litreleases_2011[['Release No.','Respondents','Date','url', 'full_text']]
df_litreleases_2011.head()
# Out:
#   Release No.  \
# 0  LR-22213
# 1  LR-22212
# 2  LR-22211
# 3  LR-22210
# 4  LR-22209
#
#                                                                                                                                    Respondents  \
# 0  Magyar Telekom Plc. and Deutsche Telekom AG and Straub, et al. See also: SEC complaint v. the companies and SEC Complaint v. the executives
# 1  Shawn R. Merriman et al.
# 2  Evolution Capital Advisors, et al.
# 3  GE Funding Capital Market Services, Inc.
# 4  Alfred S. Teo, Sr., et al.
#
#             Date                                                          url  \
# 0  Dec. 29, 2011  https://www.sec.gov/litigation/litreleases/2011/lr22213.htm
# 1  Dec. 29, 2011  https://www.sec.gov/litigation/litreleases/2011/lr22212.htm
# 2  Dec. 28, 2011  https://www.sec.gov/litigation/litreleases/2011/lr22211.htm
# 3  Dec. 23, 2011  https://www.sec.gov/litigation/litreleases/2011/lr22210.htm
# ...

# %%
# Save to CSV
df_litreleases_2011.to_csv("litreleases_2011_scraped.csv", index=False)
