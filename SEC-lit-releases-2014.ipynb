# %%
import pandas as pd
import re
import numpy as np
import requests
from bs4 import BeautifulSoup

# %%
df = pd.read_csv('SEC_lit_releases_2014.csv')

# %%
pd.set_option('display.max_colwidth', -1)

# %%
df.head()
# Out:
#   Release No.           Date  \
# 0  LR-23169    Dec. 23, 2014
# 1  LR-23168    Dec. 23, 2014
# 2  LR-23167    Dec. 22, 2014
# 3  LR-23166    Dec. 22, 2014
# 4  LR-23165    Dec. 19, 2014
#
#                                                              Action
# 0  Efstratios “Elias” D. Argyropoulos and Prima Capital Group, Inc.
# 1  E-Monee.com Inc., et al.
# 2  Shivbir S. Grewal and Preetinder Grewal
# 3  Howard B. Present See also: SEC Complaint
# 4  Frank A. Dunn, et al. Other Release No.: AAER-3617

# %%
# make a new column of lowercase release numbers to generate URL column
df['release_no'] = df['Release No.'].str.replace('-', '')
df['release_no'] = df['release_no'].str.lower()

# %%
# add the url column based on the url pattern
df['url'] = "https://www.sec.gov/litigation/litreleases/2014/" + df.release_no + ".htm"

# %%
# drop the release_no column
df = df.drop(['release_no'], axis=1)

# %%
df
# Out:
#     Release No.           Date  \
# 0    LR-23169    Dec. 23, 2014
# 1    LR-23168    Dec. 23, 2014
# 2    LR-23167    Dec. 22, 2014
# 3    LR-23166    Dec. 22, 2014
# 4    LR-23165    Dec. 19, 2014
# 5    LR-23164    Dec. 19, 2014
# 6    LR-23163    Dec. 19, 2014
# 7    LR-23162    Dec. 18, 2014
# 8    LR-23161    Dec. 18, 2014
# 9    LR-23159    Dec. 17, 2014
# 10   LR-23158    Dec. 15, 2014
# 11   LR-23157    Dec. 15, 2014
# 12   LR-23156    Dec. 12, 2014
# 13   LR-23155    Dec. 11, 2014
# 14   LR-23154    Dec. 9, 2014
# 15   LR-23153    Dec. 9, 2014
# 16   LR-23152    Dec. 8, 2014
# 17   LR-23151    Dec. 8, 2014
# 18   LR-23150    Dec. 5, 2014
# 19   LR-23149    Dec. 5, 2014
# 20   LR-23148    Dec. 4, 2014
# 21   LR-23147    Dec. 4, 2014
# 22   LR-23146    Dec. 2, 2014
# 23   LR-23145    Dec. 2, 2014
# 24   LR-23144    Nov. 26, 2014
# 25   LR-23143    Nov. 25, 2014
# 26   LR-23142    Nov. 25, 2014
# 27   LR-23141    Nov. 25, 2014
# 28   LR-23140    Nov. 24, 2014
# ...

# %%
# using BeautifulSoup to loop through each URL and pull all the text

def get_release_info(row):
    
    try:
        request = requests.get(row['url'])
        soup = BeautifulSoup(request.text, 'html.parser')
        
        full_text = soup.findAll(text=True)
        
    except:
        return pd.Series({})

    return pd.Series({
        'full_text': full_text,
    })

# %%
df_litreleases_2014 = df.apply(get_release_info, axis=1).join(df)

# %%
df_litreleases_2014.head()
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %%
df_litreleases_2014.dtypes
# Out:
# full_text      object
# Release No.    object
# Date           object
# Action         object
# url            object
# dtype: object

# %%
df_litreleases_2014['Respondents'] = df_litreleases_2014['Action']

# %%
# rearrange columns
df_litreleases_2014 = df_litreleases_2014[['Release No.','Respondents','Date','url', 'full_text']]
df_litreleases_2014.head()
# Out:
#   Release No.  \
# 0  LR-23169
# 1  LR-23168
# 2  LR-23167
# 3  LR-23166
# 4  LR-23165
#
#                                                         Respondents  \
# 0  Efstratios “Elias” D. Argyropoulos and Prima Capital Group, Inc.
# 1  E-Monee.com Inc., et al.
# 2  Shivbir S. Grewal and Preetinder Grewal
# 3  Howard B. Present See also: SEC Complaint
# 4  Frank A. Dunn, et al. Other Release No.: AAER-3617
#
#             Date                                                          url  \
# 0  Dec. 23, 2014  https://www.sec.gov/litigation/litreleases/2014/lr23169.htm
# 1  Dec. 23, 2014  https://www.sec.gov/litigation/litreleases/2014/lr23168.htm
# 2  Dec. 22, 2014  https://www.sec.gov/litigation/litreleases/2014/lr23167.htm
# 3  Dec. 22, 2014  https://www.sec.gov/litigation/litreleases/2014/lr23166.htm
# 4  Dec. 19, 2014  https://www.sec.gov/litigation/litreleases/2014/lr23165.htm
#
# ...

# %%
# Save to CSV
df_litreleases_2014.to_csv("litreleases_2014_scraped.csv", index=False)
